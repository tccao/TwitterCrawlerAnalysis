# %%
#retweet_user_data.csv

# %%
import pandas as pd 
df = pd.read_csv('/Users/udayr/Documents/retweet_user_data.csv') #Read into a df

# %%
import networkx as nx

G = nx.from_pandas_edgelist(df, 'author_id','name_user') #Turn df into graph
pos = nx.spring_layout(G) #specify layout for visual

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(10, 10))
plt.style.use('ggplot')
nodes = nx.draw_networkx_nodes(G, pos,
                               alpha=0.8)
nodes.set_edgecolor('k')
nx.draw_networkx_labels(G, pos, font_size=8)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.2)
pos = nx.spring_layout(G)
plt.savefig('twitterFollowers.png')
# Out:
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127926 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127926 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127462 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128137 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127462 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128137 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 129516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128300 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 129516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 9994 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128016 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 9994 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127752 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128016 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127952 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127952 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127870 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 129346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127870 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 129346 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127482 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127925 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 129449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127775 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127482 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127480 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127925 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 129449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127775 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127754 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2375 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2381 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2381 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2357 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2306 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127796 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127796 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127470 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128681 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127470 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128681 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 2335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2326 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 2335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127988 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 917607 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 917602 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 917619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 917603 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 917620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 917631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127487 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127988 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 917607 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 917602 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 917619 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 917603 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 917620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 917631 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128062 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127468 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128062 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 128036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127468 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\udayr\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 127469 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
G.number_of_nodes() #Find the total number of nodes in this graph
# Out:
# 224

# %%
#original_tweet_data

# %%
import pandas as pd 
df = pd.read_csv('/Users/udayr/Documents/original_tweet_data.csv') #Read into a df

# %%
import networkx as nx

G = nx.from_pandas_edgelist(df, 'author_id','tweet_id') #Turn df into graph
pos = nx.spring_layout(G) #specify layout for visual

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(10, 10))
plt.style.use('ggplot')
nodes = nx.draw_networkx_nodes(G, pos,
                               alpha=0.8)
nodes.set_edgecolor('k')
nx.draw_networkx_labels(G, pos, font_size=8)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.2)
pos = nx.spring_layout(G)
plt.savefig('twitterFollowers.png')

# %%
G.number_of_nodes() #Find the total number of nodes in this graph
# Out:
# 92

# %%
#retweet_tweets_data

# %%
import pandas as pd 
df = pd.read_csv('/Users/udayr/Documents/retweet_tweets_data.csv') #Read into a df

# %%
import networkx as nx

G = nx.from_pandas_edgelist(df, 'author_id','tweets_id') #Turn df into graph
pos = nx.spring_layout(G) #specify layout for visual

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(10, 10))
plt.style.use('ggplot')
nodes = nx.draw_networkx_nodes(G, pos,
                               alpha=0.8)
nodes.set_edgecolor('k')
nx.draw_networkx_labels(G, pos, font_size=8)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.2)
pos = nx.spring_layout(G)
plt.savefig('twitterFollowers.png')

# %%
G.number_of_nodes() #Find the total number of nodes in this graph
# Out:
# 68
