# %%
# %run -i "main0.py"
# Out:
# Endpoint Response Code: 401
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\GithubProject\TwitterCrawlerAnalysis\main0.py in <module>
#      70
#      71 if __name__ == '__main__':
# ---> 72     main()
#
# ~\GithubProject\TwitterCrawlerAnalysis\main0.py in main()
#      65
#      66     url = create_url(keyword,start_time,end_time,max_results)
# ---> 67     json_response= connect_to_endpoint(url[0],headers,url[1]);
#      68     print(json.dumps(json_response, indent=4, sort_keys=True))
#      69     print("end")
#
# ~\GithubProject\TwitterCrawlerAnalysis\main0.py in connect_to_endpoint(url, headers, params, next_token)
#      49     print("Endpoint Response Code: " + str(response.status_code))
#      50     if response.status_code != 200: #-100 processing, -200 is successfull, -300 is client errors, -400 is server error
# ---> 51         raise Exception(
#      52             "Request returned an error: {} {}".format(response.status_code,response.text)
#      53         )
#
# Exception: Request returned an error: 401 {
#   "title": "Unauthorized",
#   "type": "about:blank",
#   "status": 401,
#   "detail": "Unauthorized"
# }

# %%
# %load "main0.py"
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time
#For manage environment
#Credit to Andrew Edward for guidelines

#Export bearer_token to set environment variables
bearer_token = os.environ.get("BEARER_TOKEN")

def auth():
    return os.getenv('TOKEN')

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def create_url(keyword, start_date, end_date, max_results = 10):
    #First using search url API to pull interested keyword
    search_url = "https://api.twitter.com/2/tweets/search/recent"

    #The params that we want to use
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,#Min 10, max 100
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200: #-100 processing, -200 is successfull, -300 is client errors, -400 is server error
        raise Exception(
            "Request returned an error: {} {}".format(response.status_code,response.text)
        )
    return response.json()

def main():
    #Inputs for the request
    os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAACNMYQEAAAAADF5%2Fp5%2Fw%2FRW1OhMju0XsTjTa%2F%2FQ%3DPQT9mLoy3xLgo1T0h1oeOPqWoXbuHhfwTdwPFrmxET6teLcsG1'
    bearer_token = auth()
    headers = create_headers(bearer_token)
    keyword = "bitcoin lang:en"
    start_time = "2022-01-17T14:26:00.000Z"
    end_time =   "2022-01-23T09:37:00.000Z"
    max_results = 15

    url = create_url(keyword,start_time,end_time,max_results)
    json_response= connect_to_endpoint(url[0],headers,url[1]);
    print(json.dumps(json_response, indent=4, sort_keys=True))
    print("end")

if __name__ == '__main__':
    main()
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "author_id": "1433158342076256259",
#             "conversation_id": "1485184781449052169",
#             "created_at": "2022-01-23T09:36:59.000Z",
#             "id": "1485184781449052169",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485172750469804033",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @Sahel1377d: @BluesparrowC @tommychong I ask you\n\nWhich crypto community enjoys both untapped potential and popularity?????? \n\nUndoubted\u2026"
#         },
#         {
#             "author_id": "1086728481860395008",
#             "conversation_id": "1485184779851079689",
#             "created_at": "2022-01-23T09:36:59.000Z",
#             "id": "1485184779851079689",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2102
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485158597197770752",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @VictorIsrael_: Crypto, I don\u2019t know\nNFT, I don\u2019t know\nBitcoin, I don\u2019t know\nTech, I don\u2019t know\nCoding, I don\u2019t know\nProgramming, I don\u2019\u2026"
#         },
#         {
#             "author_id": "1144195728128036866",
#             "conversation_id": "1485184779251236865",
#             "created_at": "2022-01-23T09:36:59.000Z",
#             "id": "1485184779251236865",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2102
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485158597197770752",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @VictorIsrael_: Crypto, I don\u2019t know\nNFT, I don\u2019t know\nBitcoin, I don\u2019t know\nTech, I don\u2019t know\nCoding, I don\u2019t know\nProgramming, I don\u2019\u2026"
#         },
#         {
#             "author_id": "1444156991614619652",
#             "conversation_id": "1485184778332692488",
#             "created_at": "2022-01-23T09:36:59.000Z",
#             "id": "1485184778332692488",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4344
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485178040837619718",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @AirdropStario: \ud83d\udca7 Mighty Crew Airdrop \ud83d\udca7\n\n\ud83c\udfc6 Task:          \u2795 $30 worth of MIT for 200 random participants each.\n\n\ud83d\udc68\u200d\ud83d\udc69\u200d\ud83d\udc67 Referral:   \u2795 $40\u2026"
#         },
#         {
#             "author_id": "1460994044507484160",
#             "conversation_id": "1485184777330528261",
#             "created_at": "2022-01-23T09:36:58.000Z",
#             "id": "1485184777330528261",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "I am very thankful to @Tradecrypto11 for knowing me this dangerous #Bitcoin crash and #BTC crash. That's because of you only  I didn't cause any type of losses. A huge thankyou to you once again. #BitcoinCrash #DOT crash  \"accurate from all.\" Z"
#         },
#         {
#             "author_id": "1423363911001194502",
#             "conversation_id": "1485184775354785793",
#             "created_at": "2022-01-23T09:36:58.000Z",
#             "id": "1485184775354785793",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 20
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485175826886926337",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @Upper_Capital: This guy created a coin that will 100x and you can do nothing about it but buy&amp;stake  $MTV #MTV #MultiVAC_Global \n\n #Bit\u2026"
#         },
#         {
#             "author_id": "1368935347556552704",
#             "conversation_id": "1485184775224958976",
#             "created_at": "2022-01-23T09:36:58.000Z",
#             "id": "1485184775224958976",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 7933
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1484956487046905859",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @airdropinspect: New airdrop: Bithug (HUG)\nTotal Reward: 3,200,000 HUG\nRate: \u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\nWinners: 6,000 Random &amp; 200 Top\nDistribution: 15th\u2026"
#         },
#         {
#             "author_id": "367037139",
#             "conversation_id": "1485184774993899520",
#             "created_at": "2022-01-23T09:36:58.000Z",
#             "id": "1485184774993899520",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 135
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485023203458269186",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @Investingcom: *BITCOIN HAS LOST 50% SINCE HITTING RECORD HIGH, MORE THAN $600 BILLION IN MARKET VALUE HAS BEEN WIPED OUT\n\n#BTC #BITCOIN\u2026"
#         },
#         {
#             "author_id": "1316050244765802496",
#             "conversation_id": "1485184772699996166",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184772699996166",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1484949056979886085",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "This project make huge opportunity. Thanks for that. It is faithful and potential project.\n\n@Shaharriar1\n@ShuvoSaha00\n@MdFarhanSami1\n\n#Airdrops #RedAttack #Bitcoin #AirdropDet #Crypto https://t.co/9hHucqEn4u"
#         },
#         {
#             "author_id": "2450543949",
#             "conversation_id": "1485184771743690755",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184771743690755",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 310
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1484973936932802562",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @PomeraNaut: Congrats on the successful launch!!!\n\nHope you guys are enjoying our Staking pools!\n\nWhat are the next steps for Pomeranaut\u2026"
#         },
#         {
#             "author_id": "1203554468727406593",
#             "conversation_id": "1485184771701764099",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184771701764099",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 6711
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485173858558935040",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @airdropinspect: New airdrop: Fairdesk (FDT)\nTotal Reward: 10,000 FDT\nRate: \u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\nWinners: 3,000 Random &amp; 100 Top\nDistribution: Befor\u2026"
#         },
#         {
#             "author_id": "1444962670277496832",
#             "conversation_id": "1485184771626082304",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184771626082304",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 36
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485160408742825986",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @gate_io: \ud83d\ude0eIt's #AMA Time\n\n\ud83d\udc49Join #Gateio BD Manager Tom Rodriguez host an #AMA with Ben Lakoff, Co-founder &amp; Business Lead of @DefiNft\u2026"
#         },
#         {
#             "author_id": "1440985314827194371",
#             "conversation_id": "1485184771571740679",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184771571740679",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 19
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1485161824018649089",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @Rektem1: In the last 24 hours Bitcoin has remained flat while #SHIB has gone up 22%\n\n#SHIBA #SHIBARMY \n#AMAZONACCEPTSHIB https://t.co/5\u2026"
#         },
#         {
#             "author_id": "1322449579971768320",
#             "conversation_id": "1485184770439282689",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184770439282689",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 310
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1484973936932802562",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @PomeraNaut: Congrats on the successful launch!!!\n\nHope you guys are enjoying our Staking pools!\n\nWhat are the next steps for Pomeranaut\u2026"
#         },
#         {
#             "author_id": "1482368603710267392",
#             "conversation_id": "1485184769763823618",
#             "created_at": "2022-01-23T09:36:57.000Z",
#             "id": "1485184769763823618",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 355
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1478118742848679939",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @ZeldaInu: NEXT MASSIVE PROJECT, MAJOR LISTINGS ALREADY\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80\ud83d\ude80 @bitboy_crypto @altcoindaily @Bitcoin  #bitcoin #shibainu #zelda #dogecoin\u2026"
#         }
#     ],
#     "includes": {
#         "users": [
#             {
#                 "created_at": "2021-09-01T20:02:54.000Z",
#                 "description": "",
#                 "id": "1433158342076256259",
#                 "name": "Abdollah Madadi",
#                 "public_metrics": {
#                     "followers_count": 121,
#                     "following_count": 421,
#                     "listed_count": 0,
#                     "tweet_count": 10136
#                 },
#                 "username": "AbdollahMadadi",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-01-19T20:53:55.000Z",
#                 "description": "MedTech \ud83d\ude0a, \nTired!",
#                 "id": "1086728481860395008",
#                 "name": "\u00b6Qabid \ud83d\udc8e",
#                 "public_metrics": {
#                     "followers_count": 440,
#                     "following_count": 350,
#                     "listed_count": 0,
#                     "tweet_count": 17309
#                 },
#                 "username": "Deni_afe",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-06-27T10:48:14.000Z",
#                 "description": "Happy girl||Unapologetically annoying sometimes||Fashion designer||Accountant in making",
#                 "id": "1144195728128036866",
#                 "name": "'Nimi\ud83e\udd8b\u2764\ufe0f",
#                 "public_metrics": {
#                     "followers_count": 1169,
#                     "following_count": 1386,
#                     "listed_count": 1,
#                     "tweet_count": 3057
#                 },
#                 "username": "Iam_fiyin",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-10-02T04:27:48.000Z",
#                 "description": "",
#                 "id": "1444156991614619652",
#                 "name": "Masoud Ghch",
#                 "public_metrics": {
#                     "followers_count": 2,
#                     "following_count": 136,
#                     "listed_count": 0,
#                     "tweet_count": 130
#                 },
#                 "username": "GhchMasoud",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-11-17T15:31:52.000Z",
#                 "description": "Market analysis & recaps, scalping leverage calls, binance altcoin signals follow & search on Telegram to get our channel @tradeosiann",
#                 "id": "1460994044507484160",
#                 "name": "Crypto Life",
#                 "public_metrics": {
#                     "followers_count": 114,
#                     "following_count": 679,
#                     "listed_count": 2,
#                     "tweet_count": 8196
#                 },
#                 "username": "Crypto_life4",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-08-05T19:23:15.000Z",
#                 "description": "H",
#                 "id": "1423363911001194502",
#                 "name": "Floris Zijlstra",
#                 "public_metrics": {
#                     "followers_count": 18,
#                     "following_count": 34,
#                     "listed_count": 0,
#                     "tweet_count": 942
#                 },
#                 "username": "floris_zijlstra",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-03-08T14:43:29.000Z",
#                 "description": "I am a student\n(#CRO)",
#                 "id": "1368935347556552704",
#                 "name": "Amjad khan",
#                 "public_metrics": {
#                     "followers_count": 40,
#                     "following_count": 1873,
#                     "listed_count": 1,
#                     "tweet_count": 4925
#                 },
#                 "username": "Anjadali6",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-09-03T08:08:11.000Z",
#                 "description": "\u0e1f\u0e35\u0e25\u0e2a\u0e27\u0e22 \u0e44\u0e21\u0e48\u0e2d\u0e30\u0e44\u0e23\u0e01\u0e31\u0e1a\u0e43\u0e04\u0e23",
#                 "id": "367037139",
#                 "name": "\ud835\ude29\ud835\ude36\ud835\ude2f\ud835\ude2f\ud835\ude3a",
#                 "public_metrics": {
#                     "followers_count": 1910,
#                     "following_count": 431,
#                     "listed_count": 6,
#                     "tweet_count": 209764
#                 },
#                 "username": "hvnniet",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-10-13T16:17:04.000Z",
#                 "description": "I Am A Muslim.",
#                 "id": "1316050244765802496",
#                 "name": "Mohammad Jihad",
#                 "public_metrics": {
#                     "followers_count": 17,
#                     "following_count": 282,
#                     "listed_count": 0,
#                     "tweet_count": 772
#                 },
#                 "username": "Mohamma44409183",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-03-31T19:35:29.000Z",
#                 "description": "Keluargaku surgaku",
#                 "id": "2450543949",
#                 "name": "Maulana Ahmad",
#                 "public_metrics": {
#                     "followers_count": 81,
#                     "following_count": 1538,
#                     "listed_count": 0,
#                     "tweet_count": 4402
#                 },
#                 "username": "Maulana_Ahmad99",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-12-08T05:59:01.000Z",
#                 "description": "siapa anda ?",
#                 "id": "1203554468727406593",
#                 "name": "Aku Adalah Alien",
#                 "public_metrics": {
#                     "followers_count": 147,
#                     "following_count": 3626,
#                     "listed_count": 0,
#                     "tweet_count": 7606
#                 },
#                 "username": "AlienAdalah",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-10-04T09:49:28.000Z",
#                 "description": "\u062f\u0648\u0633\u062a\u0627\u0631 \u0637\u0628\u06cc\u0639\u062a",
#                 "id": "1444962670277496832",
#                 "name": "\u2066\ud83c\uddf8\ud83c\udde6\u2069nftbooks",
#                 "public_metrics": {
#                     "followers_count": 257,
#                     "following_count": 248,
#                     "listed_count": 0,
#                     "tweet_count": 8889
#                 },
#                 "username": "Aboomar65023301",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-09-23T10:25:40.000Z",
#                 "description": "",
#                 "id": "1440985314827194371",
#                 "name": "EricSays4",
#                 "public_metrics": {
#                     "followers_count": 19,
#                     "following_count": 52,
#                     "listed_count": 0,
#                     "tweet_count": 1634
#                 },
#                 "username": "Says4Eric",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-10-31T08:05:42.000Z",
#                 "description": "Let's win every month\nand win $1000\n#6\ufe0f\u20e35\ufe0f\u20e3\ud83c\udfb9",
#                 "id": "1322449579971768320",
#                 "name": "Esen6\ufe0f\u20e35\ufe0f\u20e3\ud83c\udfb9",
#                 "public_metrics": {
#                     "followers_count": 6519,
#                     "following_count": 6904,
#                     "listed_count": 2,
#                     "tweet_count": 78314
#                 },
#                 "username": "esenziewin",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-01-15T15:06:46.000Z",
#                 "description": "",
#                 "id": "1482368603710267392",
#                 "name": "Ani Galstyan",
#                 "public_metrics": {
#                     "followers_count": 0,
#                     "following_count": 198,
#                     "listed_count": 0,
#                     "tweet_count": 170
#                 },
#                 "username": "AniGals03825304",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1485184781449052169",
#         "next_token": "b26v89c19zqg8o3fpe477s8s12dywlanyxxuqras2eykd",
#         "oldest_id": "1485184769763823618",
#         "result_count": 15
#     }
# }
# end
